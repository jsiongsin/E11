# %%
import pandas as pd
import matplotlib.pyplot as plt
data1.columns
# Out:
# Index(['Time', 'Latitude', 'Longitude', 'PM1', 'PM25', 'PM10', 'Temperature',
#        'Humidity', 'Pressure', 'Altitude', 'VOC', 'counts'],
#       dtype='object')

# %%
data1 = pd.read_csv("Loc2_session1_group1_2024-04-12_15-53-01.csv")
data2 = pd.read_csv("Loc3_session1_group1_2024-04-12_16-01-14.csv")
data3 = pd.read_csv("Loc4_session1_group1_2024-04-12_16-12-05.csv")
data = [data1,data2,data3]
meta_data = ['counts','Temperature','PM25']

# %%
for df in meta_data:    
    for i in range(3):
        plt.hist(data[i][df])
# ignore this one, analyze bottom ones

# %%
plt.hist(data1['counts'], bins=15)
plt.hist(data2['counts'], bins=15)
plt.hist(data3['counts'], bins=15)
plt.legend(['Jacobs','Etch','Parking'])
plt.title('Radiation')
# Out:
# Text(0.5, 1.0, 'Radiation')

# %%
plt.hist(data1['Temperature'], bins=10)
plt.hist(data2['Temperature'], bins=10)
plt.hist(data3['Temperature'], bins=10)
plt.legend(['Jacobs','Etch','Parking'])
plt.title('Temperature')
# Out:
# Text(0.5, 1.0, 'Temperature')

# %%
plt.hist(data1['PM25'],bins=8)
plt.hist(data2['PM25'],bins=5)
plt.hist(data3['PM25'],bins=15)
plt.legend(['Jacobs','Etch','Parking'])
plt.title('Air Quality')
# Out:
# Text(0.5, 1.0, 'Air Quality')
